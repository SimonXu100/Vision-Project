# %%
# Load libraries and convenience functions

from IPython import display
import matplotlib.pyplot as plt
import numpy as np

def load_image(filename):
    img = np.load(filename)
    img = img.astype("float32") / 255.
    return img

def gray2rgb(image):
    return np.repeat(np.expand_dims(image, 2), 3, axis=2)

def show_image(img):
    plt.imshow(img, interpolation='nearest')

# %%
images = [load_image('red.npy'),
          load_image('green.npy'),
          load_image('blue.npy')]

show_image(gray2rgb(np.concatenate(images, axis=1)))

# %%
plt.imshow(images[0])

# %%
plt.imshow(images[1])

# %%
plt.imshow(images[2])

# %%
show_image(np.stack(images, axis=-1))

# %%
size = images[0].shape
size
# Out:
# (810, 943)

# %%
test1 = images[1].copy()
test1[::,::] = 0

# %%
test_image = [
    images[0],
    test1,
    test1
]

# %%
show_image(np.stack(test_image, axis=-1))

# %%
test_image1 = [
    test1,
    images[1],
    test1
]
show_image(np.stack(test_image1, axis=-1))

# %%
test_image01 = [
    images[0],
    images[1],
    test1
]
show_image(np.stack(test_image01, axis=-1))

# %%
test_image02 = [
    images[0],
    test1,
    images[2]
]
show_image(np.stack(test_image02, axis=-1))

# %%
test_image12 = [
    test1,
    images[1],
    images[2]
]
show_image(np.stack(test_image02, axis=-1))

# %%
test_image2 = [
    test1,
    test1,
    images[2]
    
]
show_image(np.stack(test_image2, axis=-1))
